# %% [markdown]
# <a href="https://colab.research.google.com/github/fpefigueiredo/startlearning.py/blob/main/Tarefa1_EBAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá mundo! :)")
# Out:
# Olá mundo! :)

# %% [markdown]
# ![WhatsApp Image 2023-07-31 at 11.17.53.jpeg](data:image/jpeg;base64,...)

# %%
A = 3*320.52
print(A)
# Out:
# 961.56

# %%
B = 834.47/119.21
print(B)
# Out:
# 7.000000000000001

# %%
C = 15378.12/5
print(C)
# Out:
# 3075.6240000000003

# %%
r_mundo = "Roda mundo, "
r_gig = "roda gigante, "
r_moinho = "roda moinho, "
r_piao = "roda pião."

cancao = r_mundo + r_gig + r_moinho + r_piao
print(cancao)

print('7: ' + cancao[7])
print(cancao[12:26])
# Out:
# Roda mundo, roda gigante, roda moinho, roda pião.
# 7: n
# roda gigante,

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; ' + 'é a primeira alta em 6 anos.'

selic = noticia[12:18]
ano = noticia[-7]

print(selic)
print(ano)
# Out:
# 2,75%
# 6

# %%
a = False
b = True

x = not a & b
print(x)
# Out:
# True
